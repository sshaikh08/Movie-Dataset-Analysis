# %% [markdown]
# # Analysis of The Movie Data Base Data
# ## The following analysis explores the various attributes of successful movies
#
# ### It should be noted that a movie's success can be defined a few different ways based on this data. Successfull movies and how one success may relate to another (e.g voter score vs. total revenue) will be explored by answering the following questions

# %% [markdown]
# ### -What were the most expensive movies each and their adjusted budgets for all available years in the data, and how did they compare to the most profitable and highly voted movies for that year?

# %% [markdown]
# ### -Which genres had the highest adjusted revenue year to year? Which genres were the most expensive to produce? How did the adjusted budgets of the most profitable movies compare to the most expensive genres year to year?

# %% [markdown]
# ###  -What movies had the largest adjusted revenues every year? How did they compare when analysing and comparing their various attributes (e.g genre, voter score, runtime, budget, voting score)?

# %% [markdown]
# ### -How does runtime effect adjusted revenues?

# %% [markdown]
# # Data Cleaning

# %%
#Reading the csv file into a pandas dataframe
import pandas as pd
import numpy as np

np.set_printoptions(suppress=True)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

#I created two data frame objects one that contains the orginal data set, and another that contain and edit or cleaning done
tmdb_data = pd.read_csv('tmdb-movies.csv')
tmdb_data_edited = pd.read_csv('tmdb-movies.csv')

tmdb_data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610      32.986  150000000  1513528810
# 1   76341  tt1392190      28.420  150000000   378436354
# 2  262500  tt2908446      13.113  110000000   295238201
# 3  140607  tt2488496      11.173  200000000  2068178225
# 4  168259  tt2820852       9.335  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
tmdb_data
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610      32.986  150000000  1513528810
# 1       76341  tt1392190      28.420  150000000   378436354
# 2      262500  tt2908446      13.113  110000000   295238201
# 3      140607  tt2488496      11.173  200000000  2068178225
# 4      168259  tt2820852       9.335  190000000  1506249360
# 5      281957  tt1663202       9.111  135000000   532950503
# 6       87101  tt1340138       8.654  155000000   440603537
# 7      286217  tt3659388       7.667  108000000   595380321
# 8      211672  tt2293640       7.404   74000000  1156730962
# 9      150540  tt2096673       6.327  175000000   853708609
# 10     206647  tt2379713       6.200  245000000   880674609
# 11      76757  tt1617661       6.189  176000003   183987723
# 12     264660  tt0470752       6.119   15000000    36869414
# 13     257344  tt2120120       5.985   88000000   243637091
# 14      99861  tt2395427       5.945  280000000  1405035767
# ...

# %%
tmdb_data.index

# %%
tmdb_data_edited.rename(columns = {'vote_average':'average_vote_score'}, inplace=True)

# %%
len(tmdb_data)

# %%
tmdb_data.loc[0, 'original_title']

# %%
# Test of data
tmdb_data_edited['original_title'].head()

# %%
# Test of data
tmdb_data_edited.loc[0,'original_title']

# %%
tmdb_data_edited.columns

# %%
#Locating identifying all the columns with null values
tmdb_columns_with_null = tmdb_data_edited.isnull().any()
tmdb_columns_with_null

# %%
#Printing out all the row that have an imdb_id value of Nan
tmdb_data_edited[tmdb_data_edited['imdb_id'].isnull() == True]

# %%
tmdb_data_edited.isnull().values

# %%
tmdb_data_edited.isnull().values[1]

# %%
tmdb_data_edited.isnull().values[18]

# %%
type(tmdb_data_edited.isnull().values)

# %%
tmdb_data_edited.isnull()

# %%
tmdb_data_edited[tmdb_data_edited.isnull()]

# %%
tmdb_data_edited[tmdb_data_edited.isnull().values]
#For some reason this is returning all the rows that have atleast

# %%
tmdb_data_edited[tmdb_data_edited.isnull().values]

# %%
# DataFrame containing unique rows with atleast on NaN occurrence
nan_value_occurrence_df = tmdb_data_edited[tmdb_data_edited.isnull().values].drop_duplicates()
nan_value_occurrence_df

# %%
tmdb_data_edited['homepage'].isnull() == True

# %%
# All rows that have no homepage, the purpose of this is to see if the number of columns match the amount when the original
# has been filtered out in a spreadsheet program which it did
tmdb_data_edited[tmdb_data_edited['homepage'].isnull() == True]

# %%
tmdb_data_edited.values == 0

# %%
#Returns a row if it has a zero value, will repeat if it it has more than on zero value
zero_value_occurrence_df = tmdb_data_edited[tmdb_data_edited.values == 0]

# %%
type(zero_value_occurrence_df)

# %%
# Testing on returning the index of a row at fixed position
zero_value_occurrence_df.iloc[2].name

# %%
# Demonstrating how duplicates in zero_value_occurrence_df work, as you can see from the code ran in this cell, the values for 
# the first row in the data if for the movie "Mr.Holmes". After looking at each value of the row, zero occurs twice
zero_value_occurrence_df.iloc[0]

# %%
# After print the first five values of zero_value_occurrence_df we see the data row for "Mr.Holmes" occurring twice at the very
# top of the dataframe
zero_value_occurrence_df.head()

# %%
# Created Dataframe containing unique rows from zero_value_occurrence
tmdb_zero_values = zero_value_occurrence_df.drop_duplicates()
tmdb_zero_values

# %%
len(tmdb_zero_values)

# %%
len(zero_value_occurrence_df.index)

# %%
(tmdb_data_edited == 0).any()

# %%
# Testing to see if code is working a expected
(tmdb_data_edited == 0).iloc[548].values

# %%
tmdb_zero_values.iloc[548]

# %%
#This cell demonstrates that logic is working as desired with true values above in the same location as all zeros below
print(tmdb_data_edited.iloc[548])

# %% [markdown]
# After exploring the data and trying to figure how best to clean it up, I came to the conclusion that I would be better to keep
# the data all together and create separate reference data frame which will use to account for inaccurate and misleading records
# in the data. At this point in the analysis, dataframes and corresponding reference info was created to account for
# inappropriate zero and NaN values. Additional cleaning will be conducted as needed.

# %% [markdown]
# In regards to zero values, I concluded that it didn't make sense to have them in most instances of this data set but rathar than removing the entire rows, I will only remove them from the analysis when necessary.

# %% [markdown]
# In cases where there were either or both zero values for budget and revenue, there was also a zero value for adjusted budget
# and revenue which inherently makes sense. Will continue to keep an eye of cases this does not hold true

# %% [markdown]
# # Question 1: What were the most expensive movies each year and their adjusted budgets for all available years in the data, and how did they compare to the most profitable and highly voted movies for that year?

# %%
# To start answering/analyzing the first part of this question, I'm first going to figure out about how many most expensive 
# per year there should be by finding the min and max release year. Based the data wrangling I counducted, I can see that the 
# release year column does not have any NaN or zero values I have to concern my self with

print (tmdb_data_edited == 0).any()
tmdb_columns_with_null

# %%
tmdb_data_edited['release_year'].describe()

# %%
release_year_array = np.unique(tmdb_data_edited['release_year'].values)
print(len(release_year_array))
np.sort(release_year_array)

# %% [markdown]
# Based on this information we now know that the column for 'release_year' has no NaN or zero values. Returning all the unique values demonstrates that all values are the years that range from 1960 to 2015, and we now know that we should be getting about 56 values for max budgets per year, revenues for highest revenue grossing movies per year, and voting scores for most highly voted movies per year.

# %%
# All the rows where 'release_year' == 1960 test
tmdb_data_edited[tmdb_data_edited['release_year'] == 1960].head()

# %%
# Group all the data by 'release_year'
movie_budgets_groupedby_release_year = tmdb_data_edited.groupby('release_year')['budget_adj']
movie_budgets_groupedby_release_year

# %%
# Maxes of movie_data_by_release_year
max_budget_adj_per_year = movie_budgets_groupedby_release_year.max()

# %%
type(max_budget_adj_per_year)

# %%
movies_with_max_adj_budget = tmdb_data_edited.loc[tmdb_data_edited['budget_adj'].isin(max_budget_adj_per_year.values)].sort_values(by=['release_year'])
movies_with_max_adj_budget

# %% [markdown]
# After seeing that there are more rows than expected (one for each year since 1960) I took a quick look at movies_with_max_adj_budget to see what might be the issue. I found that for some years there were multiple movies with the highest budget. For now I'm keeping and using the data as is.

# %%
tmdb_data_edited['homepage'].isnull() == True

# %%
tmdb_data_edited[tmdb_data_edited['homepage'].isnull() == True]

# %%
movies_with_max_adj_budget['release_year'].duplicated()

# %%
movies_with_max_adj_budget[movies_with_max_adj_budget['release_year'].duplicated() == True]

# %%
movies_with_max_adj_budget[['id','original_title','budget_adj','revenue_adj','release_year']]

# %%
movie_revenue_groupedby_release_year = tmdb_data_edited.groupby('release_year')['revenue_adj']
movie_revenue_groupedby_release_year

# %%
max_revenue_adj_per_year = movie_revenue_groupedby_release_year.max()

# %%
movies_with_max_adj_revenue = tmdb_data_edited.loc[tmdb_data_edited['revenue_adj'].isin(max_revenue_adj_per_year.values)].sort_values(by=['release_year'])
movies_with_max_adj_revenue

# %%
def create_df_max_by_release_year(tmdb_dataframe, column_name_string):
    column_maxes_by_release_year = tmdb_dataframe.groupby('release_year')[column_name_string].max()
    max_movies_per_year = tmdb_dataframe.loc[tmdb_dataframe[column_name_string].isin(column_maxes_by_release_year.values)].sort_values(by=['release_year'])
    return max_movies_per_year

# %%
pd.Series(movies_with_max_adj_budget['revenue_adj'].values, index=movies_with_max_adj_budget['release_year'])

# %%
duplicate_max_budgets = movies_with_max_adj_budget[movies_with_max_adj_budget['release_year'].duplicated() == True]
print('duplicate_max_budgets has ' + str(len(duplicate_max_budgets)) + ' items')
duplicate_max_budgets

# %%
duplicate_max_budgets.iloc[1]['release_year']

# %%
movies_with_max_adj_budget['release_year'].values == duplicate_max_budgets.iloc[1]['release_year']

# %%
movies_with_max_adj_budget[movies_with_max_adj_budget['release_year'].values == duplicate_max_budgets.iloc[1]['release_year']]

# %%
from random import randint

randint(0,len(duplicate_max_budgets))

# %%
movies_with_max_adj_budget[movies_with_max_adj_budget['release_year'].values == duplicate_max_budgets.iloc[randint(0,len(duplicate_max_budgets))]['release_year']]

# %%
movies_with_max_adj_budget[movies_with_max_adj_budget['release_year'].values == duplicate_max_budgets.iloc[1]['release_year']]

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

pd.Series(movies_with_max_adj_budget['revenue_adj'].values, index=movies_with_max_adj_budget['release_year']).plot(figsize=(20, 10),legend=True,label='x')
pd.Series(movies_with_max_adj_revenue['revenue_adj'].values, index=movies_with_max_adj_revenue['release_year']).plot(figsize=(20, 10),legend=True,label='y')

# %%
plt.figure(figsize=(20,10))
plt.plot(movies_with_max_adj_budget['release_year'].values,movies_with_max_adj_budget['revenue_adj'].values, label='Largest Budget Revenues')
plt.plot(movies_with_max_adj_revenue['release_year'].values,movies_with_max_adj_revenue['revenue_adj'].values, label='Highest Grossing Movie Revenues')
plt.legend()

# %%
type(movies_with_max_adj_budget)

# %%
def plot_tmdb_data_by_release_year(maxes_dataframe, column_to_plot_string, label_display_string='Not Specified'):
    plt.plot(maxes_dataframe['release_year'].values, maxes_dataframe[column_to_plot_string].values, label=label_display_string)

# %%
print(tmdb_data_edited['release_year'].min())
print (tmdb_data_edited['release_year'].max())

x_axis_numbering = np.linspace(tmdb_data_edited['release_year'].min(), tmdb_data_edited['release_year'].max(), 12)
x_axis_numbering

# %%
plt.figure(figsize=(25,10))

plt.xticks(x_axis_numbering)

plot_tmdb_data_by_release_year(movies_with_max_adj_budget, 'revenue_adj', 'Largest Budget Revenues')
plot_tmdb_data_by_release_year(movies_with_max_adj_revenue, 'revenue_adj', 'Highest Grossing Movies Revenues')

plt.legend()

# %%
movies_with_max_adj_revenue.plot(x='release_year',y='revenue_adj')
movies_with_max_adj_budget.plot(x='release_year',y='revenue_adj')

# %%
# Testing on how to obtain column names
tmdb_data_edited.columns

# %%
movies_with_max_average_vote_score = create_df_max_by_release_year(tmdb_data_edited, 'average_vote_score')
len(movies_with_max_average_vote_score)

# %%
movies_with_max_average_vote_score

# %%
max_avg_vote_score_adj_per_year = tmdb_data_edited.groupby('release_year')['average_vote_score'].max()
max_avg_vote_score_adj_per_yearmax_avg_vote_score_adj_per_year.index

# %%
movies_with_max_adj_budget[['id','original_title','budget_adj','revenue_adj','release_year']].head()

# %%
movies_with_max_adj_budget[movies_with_max_adj_budget['release_year'].values == randint(1960,2015)][['original_title','release_year','budget_adj']]

# %%
movies_with_max_adj_revenue = tmdb_data_edited.loc[tmdb_data_edited['revenue_adj'].isin(max_revenue_adj_per_year.values)].sort_values(by=['release_year'])
movies_with_max_adj_revenue.head()

# %%
max_avg_vote_score_adj_per_year.index

# %% [markdown]
# movies_with_max_adj_revenue = tmdb_data_edited.loc[tmdb_data_edited['revenue_adj'].isin(max_revenue_adj_per_year.values)].sort_values(by=['release_year'])
# movies_with_max_adj_revenue

# %%
# Highest vote score average
tmdb_data_edited[tmdb_data_edited['release_year'].values == 1960]

# %%
tmdb_data_edited['release_year'].min()

# %%
temp_df = tmdb_data_edited[tmdb_data_edited.groupby(['release_year'])['budget_adj'].transform(max) == tmdb_data_edited['budget_adj']]
temp_df.sort_values(by=['release_year'])

# %%
temp_df_2 = tmdb_data_edited[tmdb_data_edited.groupby(['release_year'])['average_vote_score'].transform(max) == tmdb_data_edited['average_vote_score']]
temp_df_2.sort_values(by=['release_year'])

# %%
def create_df_max_by_release_year(tmdb_dataframe, column_name_string):
    max_movies_per_year = tmdb_data_edited[tmdb_data_edited.groupby(['release_year'])[column_name_string].transform(max) == tmdb_data_edited[column_name_string]]
    return max_movies_per_year.sort_values(by=['release_year'])

# %%
movies_with_max_adj_budget_2 = create_df_max_by_release_year(tmdb_data_edited, 'budget_adj')
len(movies_with_max_adj_budget_2)

# %%
tmdb_data_edited[['original_title','director','runtime','genres','release_year']].head()

# %%
genre_count = pd.Series([4,4,4,4,1], index=['Action','Adventure','Science Fiction','Thriller','Fantasy'])
genre_count

# %%
genre_grid = tmdb_data_edited['genres'].str.split('|',expand=True)
genre_grid

# %%
type(genre_grid[0].value_counts())

# %%
A = genre_grid[0].value_counts().sort_index()
B = genre_grid[1].value_counts().sort_index()
C = genre_grid[2].value_counts().sort_index()
D = genre_grid[3].value_counts().sort_index()
E = genre_grid[4].value_counts().sort_index()

# %%
print A
print B
print C
print D
print E

# %%
genre_grid[4].value_counts().sort_index()

# %%
sumAB = A.add(B,fill_value = 0)
sumAB

# %%
sumCD = C.add(D,fill_value = 0)
sumCD

# %%
(sumAB + sumCD).add(E, fill_value = 0)
